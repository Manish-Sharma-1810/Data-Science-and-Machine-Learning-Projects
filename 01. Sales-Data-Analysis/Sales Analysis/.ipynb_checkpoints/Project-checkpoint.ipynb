# %% [markdown]
# # Sales Analysis Using Python

# %% [markdown]
# Import necessary libraries

# %%
import os
import pandas as pd

# %%
# Check Data of a month (April)
April_df = pd.read_csv("Sales_Data/Sales_April_2019.csv")
April_df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %% [markdown]
# ## Task-1: Merging 12 Months of sales data into a single file

# %%
# Define path of all data files
path = "Sales_Data"

# Take all the files from the directory
files = [file for file in os.listdir(path)]

# %%
# Now Check all files
for file in files:
    print(file)
print("\nTotal Number of files are : ", len(files))
# Out:
# Sales_January_2019.csv
# Sales_September_2019.csv
# Sales_June_2019.csv
# Sales_February_2019.csv
# Sales_March_2019.csv
# Sales_July_2019.csv
# Sales_August_2019.csv
# Sales_November_2019.csv
# Sales_December_2019.csv
# Sales_May_2019.csv
# Sales_April_2019.csv
# Sales_October_2019.csv
#
# Total Number of files are :  12

# %%
# Check Data of a month (June)
June_df = pd.read_csv("Sales_Data/Sales_June_2019.csv")
June_df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       209921        USB-C Charging Cable                1      11.95
# 1       209922          Macbook Pro Laptop                1     1700.0
# 2       209923             ThinkPad Laptop                1     999.99
# 3       209924            27in FHD Monitor                1     149.99
# 4       209925  Bose SoundSport Headphones                1      99.99
# ...        ...                         ...              ...        ...
# 13617   222905      AAA Batteries (4-pack)                1       2.99
# 13618   222906            27in FHD Monitor                1     149.99
# 13619   222907        USB-C Charging Cable                1      11.95
# 13620   222908        USB-C Charging Cable                1      11.95
# 13621   222909      AAA Batteries (4-pack)                1       2.99
#
#            Order Date                       Purchase Address
# ...

# %%
# Now concatinate all files into a single csv

# Create an empty DataFrame
all_months_data = pd.DataFrame()

# Now read each file and append them one by one into the 'all_months_data' DataFrame.
for file in files:
    current_data = pd.read_csv(path+"/"+file)
    all_months_data = pd.concat([all_months_data, current_data])

# %%
# Check all months data
all_months_data
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 0       141234                    iPhone                1        700
# 1       141235  Lightning Charging Cable                1      14.95
# 2       141236          Wired Headphones                2      11.99
# 3       141237          27in FHD Monitor                1     149.99
# 4       141238          Wired Headphones                1      11.99
# ...        ...                       ...              ...        ...
# 20374   278792     AA Batteries (4-pack)                1       3.84
# 20375   278793          Wired Headphones                1      11.99
# 20376   278794     AA Batteries (4-pack)                1       3.84
# 20377   278795                    iPhone                1        700
# 20378   278796          Wired Headphones                1      11.99
#
#            Order Date                         Purchase Address
# 0      01/22/19 21:25          944 Walnut St, Boston, MA 02215
# ...

# %%
# Make a csv file of all months data
all_months_data.to_csv("all_data.csv", index=False)

# %% [markdown]
# **Read in updated DataFrame**

# %%
# Create dataframe for all data
all_data = pd.read_csv('all_data.csv')
all_data
# Out:
#        Order ID                   Product Quantity Ordered Price Each  \
# 0        141234                    iPhone                1        700
# 1        141235  Lightning Charging Cable                1      14.95
# 2        141236          Wired Headphones                2      11.99
# 3        141237          27in FHD Monitor                1     149.99
# 4        141238          Wired Headphones                1      11.99
# ...         ...                       ...              ...        ...
# 186845   278792     AA Batteries (4-pack)                1       3.84
# 186846   278793          Wired Headphones                1      11.99
# 186847   278794     AA Batteries (4-pack)                1       3.84
# 186848   278795                    iPhone                1        700
# 186849   278796          Wired Headphones                1      11.99
#
#             Order Date                         Purchase Address
# ...

# %%
# Information about dataframe
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186850 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 8.6+ MB

# %%
# Describe the dataframe
all_data.describe()
# Out:
#         Order ID               Product Quantity Ordered Price Each  \
# count     186305                186305           186305     186305
# unique    178438                    20               10         24
# top     Order ID  USB-C Charging Cable                1      11.95
# freq         355                 21903           168552      21903
#
#         Order Date  Purchase Address
# count       186305            186305
# unique      142396            140788
# top     Order Date  Purchase Address
# freq           355               355

# %% [markdown]
# ## Task-2: Clean up the data!
#
# The first step in this is figuring out what we need to clean. I have found in practice, that you find things you need to clean as you perform operations and get errors. Based on the error, you decide how you should go about cleaning the data

# %%
# Import the visualizing libraries
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Check the missing data or NaN values
# False = Data is not missing
# True = Data is missing

all_data.isna()
# Out:
#         Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 0          False    False             False       False       False
# 1          False    False             False       False       False
# 2          False    False             False       False       False
# 3          False    False             False       False       False
# 4          False    False             False       False       False
# ...          ...      ...               ...         ...         ...
# 186845     False    False             False       False       False
# 186846     False    False             False       False       False
# 186847     False    False             False       False       False
# 186848     False    False             False       False       False
# 186849     False    False             False       False       False
#
#         Purchase Address
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# ...

# %%
# We can use seaborn to create a simple heatmap to see where we have missing data!
# Now creating the heatmap to check the missing data or NaN values

plt.figure(figsize=(16,8))
sns.heatmap(all_data.isna(), yticklabels=False, cbar=False, cmap='viridis')
plt.tight_layout()

# %% [markdown]
# In above heat map we can see that there are some rows which are completely NaN

# %%
# Returns NaN rows
all_data[all_data.isna().any(axis=1)]
# Out:
#        Order ID Product Quantity Ordered Price Each Order Date  \
# 664         NaN     NaN              NaN        NaN        NaN
# 678         NaN     NaN              NaN        NaN        NaN
# 797         NaN     NaN              NaN        NaN        NaN
# 876         NaN     NaN              NaN        NaN        NaN
# 1299        NaN     NaN              NaN        NaN        NaN
# ...         ...     ...              ...        ...        ...
# 184390      NaN     NaN              NaN        NaN        NaN
# 184779      NaN     NaN              NaN        NaN        NaN
# 185239      NaN     NaN              NaN        NaN        NaN
# 185614      NaN     NaN              NaN        NaN        NaN
# 185993      NaN     NaN              NaN        NaN        NaN
#
#        Purchase Address
# 664                 NaN
# 678                 NaN
# 797                 NaN
# 876                 NaN
# 1299                NaN
# ...                 ...
# 184390              NaN
# ...

# %%
# Drop all NaN rows from the dataframe
all_data = all_data.dropna(how = 'all')
all_data
# Out:
#        Order ID                   Product Quantity Ordered Price Each  \
# 0        141234                    iPhone                1        700
# 1        141235  Lightning Charging Cable                1      14.95
# 2        141236          Wired Headphones                2      11.99
# 3        141237          27in FHD Monitor                1     149.99
# 4        141238          Wired Headphones                1      11.99
# ...         ...                       ...              ...        ...
# 186845   278792     AA Batteries (4-pack)                1       3.84
# 186846   278793          Wired Headphones                1      11.99
# 186847   278794     AA Batteries (4-pack)                1       3.84
# 186848   278795                    iPhone                1        700
# 186849   278796          Wired Headphones                1      11.99
#
#             Order Date                         Purchase Address
# ...

# %% [markdown]
# **Get rid of text in 'Order Date' column**

# %%
# Find 'Or' in Order Date column
temp_df = all_data[all_data['Order Date'].str[0:2] == 'Or']
temp_df
# Out:
#         Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 1073    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1102    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1194    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1897    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2463    Order ID  Product  Quantity Ordered  Price Each  Order Date
# ...          ...      ...               ...         ...         ...
# 184502  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 184542  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 185088  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 185359  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 186774  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#         Purchase Address
# 1073    Purchase Address
# 1102    Purchase Address
# 1194    Purchase Address
# 1897    Purchase Address
# ...

# %%
# Reset new all_data
all_data = all_data[all_data['Order Date'].str[0:2]!='Or']
all_data
# Out:
#        Order ID                   Product Quantity Ordered Price Each  \
# 0        141234                    iPhone                1        700
# 1        141235  Lightning Charging Cable                1      14.95
# 2        141236          Wired Headphones                2      11.99
# 3        141237          27in FHD Monitor                1     149.99
# 4        141238          Wired Headphones                1      11.99
# ...         ...                       ...              ...        ...
# 186845   278792     AA Batteries (4-pack)                1       3.84
# 186846   278793          Wired Headphones                1      11.99
# 186847   278794     AA Batteries (4-pack)                1       3.84
# 186848   278795                    iPhone                1        700
# 186849   278796          Wired Headphones                1      11.99
#
#             Order Date                         Purchase Address
# ...

# %% [markdown]
# # Task-3 : Add Months column in the DataFrame

# %%
# Check the type of 'Order Date' column
type(all_data['Order Date'].iloc[0])
# Out:
# str

# %%
# Copy the dataframe
df = all_data.copy()
df
# Out:
#        Order ID                   Product Quantity Ordered Price Each  \
# 0        141234                    iPhone                1        700
# 1        141235  Lightning Charging Cable                1      14.95
# 2        141236          Wired Headphones                2      11.99
# 3        141237          27in FHD Monitor                1     149.99
# 4        141238          Wired Headphones                1      11.99
# ...         ...                       ...              ...        ...
# 186845   278792     AA Batteries (4-pack)                1       3.84
# 186846   278793          Wired Headphones                1      11.99
# 186847   278794     AA Batteries (4-pack)                1       3.84
# 186848   278795                    iPhone                1        700
# 186849   278796          Wired Headphones                1      11.99
#
#             Order Date                         Purchase Address
# ...

# %%
# Add the 'Month' column into the dataframe
df['Month'] = df['Order Date'].apply(lambda date : date.split("/")[0])

# %%
df
# Out:
#        Order ID                   Product Quantity Ordered Price Each  \
# 0        141234                    iPhone                1        700
# 1        141235  Lightning Charging Cable                1      14.95
# 2        141236          Wired Headphones                2      11.99
# 3        141237          27in FHD Monitor                1     149.99
# 4        141238          Wired Headphones                1      11.99
# ...         ...                       ...              ...        ...
# 186845   278792     AA Batteries (4-pack)                1       3.84
# 186846   278793          Wired Headphones                1      11.99
# 186847   278794     AA Batteries (4-pack)                1       3.84
# 186848   278795                    iPhone                1        700
# 186849   278796          Wired Headphones                1      11.99
#
#             Order Date                         Purchase Address Month
# ...

# %%
# Check the total number of unique values in the 'Month' column
df['Month'].nunique()
# Out:
# 12

# %%
# Check the formath of the 'Month' column
type(df['Month'].iloc[0])
# Out:
# str

# %%
# Now convert the 'Month' column from 'str' format to 'int' format.
df['Month'] = df['Month'].astype('int32')

# %%
# Now further Check the formath of the 'Month' column
type(df['Month'].iloc[0])
# Out:
# numpy.int32

# %% [markdown]
# # Task-4 : Add City column with their state name in the dataframe

# %%
df
# Out:
#        Order ID                   Product Quantity Ordered Price Each  \
# 0        141234                    iPhone                1        700
# 1        141235  Lightning Charging Cable                1      14.95
# 2        141236          Wired Headphones                2      11.99
# 3        141237          27in FHD Monitor                1     149.99
# 4        141238          Wired Headphones                1      11.99
# ...         ...                       ...              ...        ...
# 186845   278792     AA Batteries (4-pack)                1       3.84
# 186846   278793          Wired Headphones                1      11.99
# 186847   278794     AA Batteries (4-pack)                1       3.84
# 186848   278795                    iPhone                1        700
# 186849   278796          Wired Headphones                1      11.99
#
#             Order Date                         Purchase Address  Month
# ...

# %%
# Check a single address
df['Purchase Address'].iloc[0]
# Out:
# '944 Walnut St, Boston, MA 02215'

# %% [markdown]
# **Note**: Here we can see that city name at the first position and state name at the second position.

# %%
# Return the city name and state name of first address of the datafeame
# strip(" ") is use for removing space from the string

city_name  = df['Purchase Address'].iloc[0].split(",")[1].strip(" ")
state_name = df['Purchase Address'].iloc[0].split(",")[2].split(" ")[1]
print(city_name)
print(state_name)
# Out:
# Boston
# MA

# %%
# Now define a methods which return city name and state name by takin address as an argument.

# Define the method for returning the city name
def get_city(address):
    return address.split(",")[1].strip(" ")

# Define the method for returning the state name
def get_state(address):
    return address.split(",")[2].split(" ")[1]

# Add the 'City' column into the datafrmae ad fill the cities with their respective states
df['City'] = df['Purchase Address'].apply(lambda x: f"{get_city(x)}  ({get_state(x)})")

# %%
df
# Out:
#        Order ID                   Product Quantity Ordered Price Each  \
# 0        141234                    iPhone                1        700
# 1        141235  Lightning Charging Cable                1      14.95
# 2        141236          Wired Headphones                2      11.99
# 3        141237          27in FHD Monitor                1     149.99
# 4        141238          Wired Headphones                1      11.99
# ...         ...                       ...              ...        ...
# 186845   278792     AA Batteries (4-pack)                1       3.84
# 186846   278793          Wired Headphones                1      11.99
# 186847   278794     AA Batteries (4-pack)                1       3.84
# 186848   278795                    iPhone                1        700
# 186849   278796          Wired Headphones                1      11.99
#
#             Order Date                         Purchase Address  Month  \
# ...

# %% [markdown]
# # Task-5 : Exploratory Data Analysis (EDA)

# %% [markdown]
# ### **Question 1:** What was the best month for sales? How much was earned that month?

# %% [markdown]
# **Add the sales column into the datafrmae**

# %%
# df['Sales'] = df['Quantity Ordered'] * df['Price Each']

# %%
type(df['Quantity Ordered'].iloc[0])
# Out:
# str

# %%
type(df['Price Each'].iloc[0])
# Out:
# str

# %% [markdown]
# **Convert columns to the correct type**

# %%
df['Quantity Ordered'] = pd.to_numeric(df['Quantity Ordered']) # make int type
df['Price Each'] = pd.to_numeric(df['Price Each']) # make float type

# %%
df['Sales'] = df['Quantity Ordered'] * df['Price Each']

# %%
# Alternative Method
# all_data['Sales'] = all_data['Quantity Ordered'].astype('int') * all_data['Price Each'].astype('float')

# %%
df
# Out:
#        Order ID                   Product  Quantity Ordered  Price Each  \
# 0        141234                    iPhone                 1      700.00
# 1        141235  Lightning Charging Cable                 1       14.95
# 2        141236          Wired Headphones                 2       11.99
# 3        141237          27in FHD Monitor                 1      149.99
# 4        141238          Wired Headphones                 1       11.99
# ...         ...                       ...               ...         ...
# 186845   278792     AA Batteries (4-pack)                 1        3.84
# 186846   278793          Wired Headphones                 1       11.99
# 186847   278794     AA Batteries (4-pack)                 1        3.84
# 186848   278795                    iPhone                 1      700.00
# 186849   278796          Wired Headphones                 1       11.99
#
#             Order Date                         Purchase Address  Month  \
# ...

# %%
# groupby Months and then sum
Month_sales = df.groupby(['Month']).sum()
Month_sales
# Out:
#        Quantity Ordered    Price Each         Sales
# Month
# 1                 10903  1.811768e+06  1.822257e+06
# 2                 13449  2.188885e+06  2.202022e+06
# 3                 17005  2.791208e+06  2.807100e+06
# 4                 20558  3.367671e+06  3.390670e+06
# 5                 18667  3.135125e+06  3.152607e+06
# 6                 15253  2.562026e+06  2.577802e+06
# 7                 16072  2.632540e+06  2.647776e+06
# 8                 13448  2.230345e+06  2.244468e+06
# 9                 13109  2.084992e+06  2.097560e+06
# 10                22703  3.715555e+06  3.736727e+06
# 11                19798  3.180601e+06  3.199603e+06
# 12                28114  4.588415e+06  4.613443e+06

# %%
# Return the maximum sale and the month of maximum sales

Month_sales['Sales'].max()
# Out:
# 4613443.34000153

# %%
# Visualizing sales by months using matplotlib

months = range(1,13)
print(months)

plt.figure(figsize=(20,10))
plt.bar(months, Month_sales['Sales'])
plt.xticks(months)
plt.ylabel('Sales in USD ($)')
plt.xlabel('Month number')
plt.tight_layout()
plt.show()
# Out:
# range(1, 13)

# %% [markdown]
# #### **Answer :**
# * **December** is the best month for sale and **$4613443.34000153 USD** was earned in this months.

# %% [markdown]
# ### **Question 1:** What city had the highest number of sales?

# %%
# groupby City and then sum
City_sales = df.groupby(['City']).sum()
City_sales
# Out:
#                      Quantity Ordered    Price Each   Month         Sales
# City
# Atlanta  (GA)                   16602  2.779908e+06  104794  2.795499e+06
# Austin  (TX)                    11153  1.809874e+06   69829  1.819582e+06
# Boston  (MA)                    22528  3.637410e+06  141112  3.661642e+06
# Dallas  (TX)                    16730  2.752628e+06  104620  2.767975e+06
# Los Angeles  (CA)               33289  5.421435e+06  208325  5.452571e+06
# New York City  (NY)             27932  4.635371e+06  175741  4.664317e+06
# Portland  (ME)                   2750  4.471892e+05   17144  4.497583e+05
# Portland  (OR)                  11303  1.860558e+06   70621  1.870732e+06
# San Francisco  (CA)             50239  8.211462e+06  315520  8.262204e+06
# Seattle  (WA)                   16553  2.733296e+06  104941  2.747755e+06

# %%
# Store all cities in an array
# Maintain the order of the cities as of dataframe 'City_sales'

cities = [city for city, df in City_sales.groupby(['City'])]

# %%
# Maximum sale in a city
City_sales['Sales'].max()
# Out:
# 8262203.910004006

# %%
# Visualizing sales by city using matplotlib

plt.figure(figsize=(20,16))
plt.bar(cities, City_sales['Sales'])
plt.xticks(cities, rotation='vertical', size=16)
plt.ylabel('Sales in USD ($)', size=20)
plt.xlabel('City Name')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### **Answer :**
# * **San Francisco** is the best city in USA for sale and **$8262203.910004006 USD** was earned in this city.

# %% [markdown]
# ### **Question - 3:** What time should we display advertisements to maximize likelihood of customer's buying product?

# %%
df
# Out:
#        Order ID                   Product  Quantity Ordered  Price Each  \
# 0        141234                    iPhone                 1      700.00
# 1        141235  Lightning Charging Cable                 1       14.95
# 2        141236          Wired Headphones                 2       11.99
# 3        141237          27in FHD Monitor                 1      149.99
# 4        141238          Wired Headphones                 1       11.99
# ...         ...                       ...               ...         ...
# 186845   278792     AA Batteries (4-pack)                 1        3.84
# 186846   278793          Wired Headphones                 1       11.99
# 186847   278794     AA Batteries (4-pack)                 1        3.84
# 186848   278795                    iPhone                 1      700.00
# 186849   278796          Wired Headphones                 1       11.99
#
#             Order Date                         Purchase Address  Month  \
# ...

# %%
# Check the type of 'Order Date'
type(df['Order Date'].iloc[0])
# Out:
# str

# %%
# Convert the 'Order Date' from string object to datetime object
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
# Further check the type of 'Order Date'
type(df['Order Date'].iloc[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# Now add 'Hour' and 'Minute' columns into the dataframe
df['Hour'] = df['Order Date'].apply(lambda time : time.hour)
df['Minute'] = df['Order Date'].apply(lambda time : time.minute)

# %%
##### Alternate Method #####

# all_data['Hour'] = pd.to_datetime(all_data['Order Date']).dt.hour
# all_data['Minute'] = pd.to_datetime(all_data['Order Date']).dt.minute

# %%
type(df['Hour'].iloc[0])
# Out:
# numpy.int64

# %%
# Add a Count column in the dataframe
df['Count'] = 1
df
# Out:
#        Order ID                   Product  Quantity Ordered  Price Each  \
# 0        141234                    iPhone                 1      700.00
# 1        141235  Lightning Charging Cable                 1       14.95
# 2        141236          Wired Headphones                 2       11.99
# 3        141237          27in FHD Monitor                 1      149.99
# 4        141238          Wired Headphones                 1       11.99
# ...         ...                       ...               ...         ...
# 186845   278792     AA Batteries (4-pack)                 1        3.84
# 186846   278793          Wired Headphones                 1       11.99
# 186847   278794     AA Batteries (4-pack)                 1        3.84
# 186848   278795                    iPhone                 1      700.00
# 186849   278796          Wired Headphones                 1       11.99
#
#                 Order Date                         Purchase Address  Month  \
# ...

# %%
# groupby Houre and then sum
Hour_sales = df.groupby(['Hour']).count()
Hour_sales
# Out:
#       Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# Hour
# 0         3910     3910              3910        3910        3910
# 1         2350     2350              2350        2350        2350
# 2         1243     1243              1243        1243        1243
# 3          831      831               831         831         831
# 4          854      854               854         854         854
# 5         1321     1321              1321        1321        1321
# 6         2482     2482              2482        2482        2482
# 7         4011     4011              4011        4011        4011
# 8         6256     6256              6256        6256        6256
# 9         8748     8748              8748        8748        8748
# 10       10944    10944             10944       10944       10944
# 11       12411    12411             12411       12411       12411
# 12       12587    12587             12587       12587       12587
# ...

# %%
# Store all hours in an array
# Maintain the order of the hours as of dataframe 'Hour_sales'

hours = [hour for hour, df in Hour_sales.groupby(['Hour'])]

# %%
# Visualizing sales by hours using matplotlib

plt.figure(figsize=(20,10))
plt.plot(hours, Hour_sales['Count'], lw=2, marker='o', color='r')
plt.xticks(hours)
plt.ylabel('Number of Orders',size=20)
plt.xlabel('Hours of a day',size=20)
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# #### **Answer :**
# * **11 AM to 12 PM** or **7 PM** is the best time for displaying advertisements to maximize likelihood of customer's buying product.

# %% [markdown]
# ### **Question 4:** What products are most often sold together?

# %% [markdown]
# #### **Note :**
# * If two products have same Order Id, have been ordered together.
# * So, we have to **counts duplicate same Order IDs**.

# %%
# Create a new dataframe in which duplicate IDs will be together
# https://stackoverflow.com/questions/43348194/pandas-select-rows-if-id-appear-several-time

df1 = df[df['Order ID'].duplicated(keep=False)]
df1
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 41       141275        USB-C Charging Cable                 1       11.95
# 42       141275            Wired Headphones                 1       11.99
# 57       141290    Apple Airpods Headphones                 1      150.00
# 58       141290       AA Batteries (4-pack)                 3        3.84
# 133      141365             Vareebadd Phone                 1      400.00
# ...         ...                         ...               ...         ...
# 186756   278706        USB-C Charging Cable                 1       11.95
# 186760   278710        USB-C Charging Cable                 1       11.95
# 186761   278710            27in FHD Monitor                 1      149.99
# 186769   278718        USB-C Charging Cable                 1       11.95
# 186770   278718  Bose SoundSport Headphones                 1       99.99
#
#                 Order Date                        Purchase Address  Month  \
# ...

# %%
# Groupby 'Order ID' and make column 'Grouped' in which add products (separated by comma) with same Order ID.
# Referenced: https://stackoverflow.com/questions/27298178/concatenate-strings-from-several-rows-using-pandas-groupby

df1['Grouped'] = df1.groupby('Order ID')['Product'].transform(lambda x : ','.join(x))
# Out:
# <ipython-input-58-8635b89244d3>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Grouped'] = df1.groupby('Order ID')['Product'].transform(lambda x : ','.join(x))

# %%
df1
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 41       141275        USB-C Charging Cable                 1       11.95
# 42       141275            Wired Headphones                 1       11.99
# 57       141290    Apple Airpods Headphones                 1      150.00
# 58       141290       AA Batteries (4-pack)                 3        3.84
# 133      141365             Vareebadd Phone                 1      400.00
# ...         ...                         ...               ...         ...
# 186756   278706        USB-C Charging Cable                 1       11.95
# 186760   278710        USB-C Charging Cable                 1       11.95
# 186761   278710            27in FHD Monitor                 1      149.99
# 186769   278718        USB-C Charging Cable                 1       11.95
# 186770   278718  Bose SoundSport Headphones                 1       99.99
#
#                 Order Date                        Purchase Address  Month  \
# ...

# %%
# Now drop the duplicate rows

df2 = df1[['Order ID', 'Grouped']].drop_duplicates()

# %%
df2
# Out:
#        Order ID                                          Grouped
# 41       141275            USB-C Charging Cable,Wired Headphones
# 57       141290   Apple Airpods Headphones,AA Batteries (4-pack)
# 133      141365                 Vareebadd Phone,Wired Headphones
# 153      141384                Google Phone,USB-C Charging Cable
# 220      141450          Google Phone,Bose SoundSport Headphones
# ...         ...                                              ...
# 186700   278653                  iPhone,Lightning Charging Cable
# 186745   278697          Wired Headphones,27in 4K Gaming Monitor
# 186755   278706                Google Phone,USB-C Charging Cable
# 186760   278710            USB-C Charging Cable,27in FHD Monitor
# 186769   278718  USB-C Charging Cable,Bose SoundSport Headphones
#
# [7136 rows x 2 columns]

# %%
# Import some more libraries for counting and combinations
# Referenced: https://stackoverflow.com/questions/52195887/counting-unique-pairs-of-numbers-into-a-python-dictionary

from itertools import combinations
from collections import Counter

# %%
count = Counter()

# Most common 2:
for row in df2['Grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list, 2)))

# %%
# Print 10 most common products which was sold together
for key,value in count.most_common(10):
    print(key, value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92

# %% [markdown]
# ### Answer:
# * **iPhone** and **Lightning Charging Cable** are most often sold together.

# %%
# Most commonly sold three items together

count = Counter()

# Most common 3:
for row in df2['Grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list, 3)))
    
for key,value in count.most_common(10):
    print(key, value)
# Out:
# ('Google Phone', 'USB-C Charging Cable', 'Wired Headphones') 87
# ('iPhone', 'Lightning Charging Cable', 'Wired Headphones') 62
# ('iPhone', 'Lightning Charging Cable', 'Apple Airpods Headphones') 47
# ('Google Phone', 'USB-C Charging Cable', 'Bose SoundSport Headphones') 35
# ('Vareebadd Phone', 'USB-C Charging Cable', 'Wired Headphones') 33
# ('iPhone', 'Apple Airpods Headphones', 'Wired Headphones') 27
# ('Google Phone', 'Bose SoundSport Headphones', 'Wired Headphones') 24
# ('Vareebadd Phone', 'USB-C Charging Cable', 'Bose SoundSport Headphones') 16
# ('Vareebadd Phone', 'Bose SoundSport Headphones', 'Wired Headphones') 5
# ('USB-C Charging Cable', 'Bose SoundSport Headphones', 'Wired Headphones') 5

# %% [markdown]
# Google Phone, USB-C Charging Cable and Wired Headphones are most three items sold together

# %% [markdown]
# ### **Question-5 :** What product sold the most? Why do you think it sold the most?

# %%
df
# Out:
#        Order ID                   Product  Quantity Ordered  Price Each  \
# 0        141234                    iPhone                 1      700.00
# 1        141235  Lightning Charging Cable                 1       14.95
# 2        141236          Wired Headphones                 2       11.99
# 3        141237          27in FHD Monitor                 1      149.99
# 4        141238          Wired Headphones                 1       11.99
# ...         ...                       ...               ...         ...
# 186845   278792     AA Batteries (4-pack)                 1        3.84
# 186846   278793          Wired Headphones                 1       11.99
# 186847   278794     AA Batteries (4-pack)                 1        3.84
# 186848   278795                    iPhone                 1      700.00
# 186849   278796          Wired Headphones                 1       11.99
#
#                 Order Date                         Purchase Address  Month  \
# ...

# %%
# Groupby 'Product'
product_group = df.groupby('Product')
product_group.sum()
# Out:
#                             Quantity Ordered  Price Each   Month       Sales  \
# Product
# 20in Monitor                            4129   451068.99   29336   454148.71
# 27in 4K Gaming Monitor                  6244  2429637.70   44440  2435097.56
# 27in FHD Monitor                        7550  1125974.93   52558  1132424.50
# 34in Ultrawide Monitor                  6199  2348718.19   43304  2355558.01
# AA Batteries (4-pack)                  27635    79015.68  145558   106118.40
# AAA Batteries (4-pack)                 31017    61716.59  146370    92740.83
# Apple Airpods Headphones               15661  2332350.00  109477  2349150.00
# Bose SoundSport Headphones             13457  1332366.75   94113  1345565.43
# Flatscreen TV                           4819  1440000.00   34224  1445700.00
# Google Phone                            5532  3315000.00   38305  3319200.00
# LG Dryer                                 646   387600.00    4383   387600.00
# ...

# %%
# From groupby product and return 'Quantity Ordered'
quantity_ordered = product_group.sum()['Quantity Ordered']
quantity_ordered
# Out:
# Product
# 20in Monitor                   4129
# 27in 4K Gaming Monitor         6244
# 27in FHD Monitor               7550
# 34in Ultrawide Monitor         6199
# AA Batteries (4-pack)         27635
# AAA Batteries (4-pack)        31017
# Apple Airpods Headphones      15661
# Bose SoundSport Headphones    13457
# Flatscreen TV                  4819
# Google Phone                   5532
# LG Dryer                        646
# LG Washing Machine              666
# Lightning Charging Cable      23217
# Macbook Pro Laptop             4728
# ThinkPad Laptop                4130
# USB-C Charging Cable          23975
# Vareebadd Phone                2068
# Wired Headphones              20557
# iPhone                         6849
# Name: Quantity Ordered, dtype: int64

# %%
products = [product for product, df in product_group]

# %%
plt.figure(figsize=(20,15))
plt.bar(products, quantity_ordered, color='orange')
plt.xticks(hours, rotation='vertical', size=20)
plt.ylabel('Quantity Ordered',size=20)
plt.xlabel('Products', size=20)
plt.grid()
plt.tight_layout()
plt.show()

# %%
prices = df.groupby('Product').mean()['Price Each']
prices
# Out:
# Product
# 20in Monitor                   109.99
# 27in 4K Gaming Monitor         389.99
# 27in FHD Monitor               149.99
# 34in Ultrawide Monitor         379.99
# AA Batteries (4-pack)            3.84
# AAA Batteries (4-pack)           2.99
# Apple Airpods Headphones       150.00
# Bose SoundSport Headphones      99.99
# Flatscreen TV                  300.00
# Google Phone                   600.00
# LG Dryer                       600.00
# LG Washing Machine             600.00
# Lightning Charging Cable        14.95
# Macbook Pro Laptop            1700.00
# ThinkPad Laptop                999.99
# USB-C Charging Cable            11.95
# Vareebadd Phone                400.00
# Wired Headphones                11.99
# iPhone                         700.00
# Name: Price Each, dtype: float64

# %%
# Visualizing products Quantity Ordered over Prices

fig, ax1 = plt.subplots(figsize=(20,10) )

ax2 = ax1.twinx()
ax1.bar(products, quantity_ordered, color='orange')
ax2.plot(products, prices, color='b')

ax1.set_xlabel('Product Name', size=20)
ax1.set_ylabel('Quantity Ordered', color='orange', size=20)
ax2.set_ylabel('Price ($)', color='b', size=20)
ax1.set_xticklabels(products, rotation='vertical', size=20)
# Out:
# [Text(0, 0, '20in Monitor'),
#  Text(0, 0, '27in 4K Gaming Monitor'),
#  Text(0, 0, '27in FHD Monitor'),
#  Text(0, 0, '34in Ultrawide Monitor'),
#  Text(0, 0, 'AA Batteries (4-pack)'),
#  Text(0, 0, 'AAA Batteries (4-pack)'),
#  Text(0, 0, 'Apple Airpods Headphones'),
#  Text(0, 0, 'Bose SoundSport Headphones'),
#  Text(0, 0, 'Flatscreen TV'),
#  Text(0, 0, 'Google Phone'),
#  Text(0, 0, 'LG Dryer'),
#  Text(0, 0, 'LG Washing Machine'),
#  Text(0, 0, 'Lightning Charging Cable'),
#  Text(0, 0, 'Macbook Pro Laptop'),
#  Text(0, 0, 'ThinkPad Laptop'),
#  Text(0, 0, 'USB-C Charging Cable'),
#  Text(0, 0, 'Vareebadd Phone'),
#  Text(0, 0, 'Wired Headphones'),
#  Text(0, 0, 'iPhone')]

# %% [markdown]
# ### Answer:
# * Products have low prices, most likely to sold (eg. AAA Batteries, AA Batteries etc.) and products have high prices are less likely to sold (eg. LG Washing Machine, LG Dryer etc.).

# %% [markdown]
# # Thank you
