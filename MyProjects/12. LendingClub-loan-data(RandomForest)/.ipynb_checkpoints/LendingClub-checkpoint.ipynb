# %% [markdown]
# # LendingClub.com Project (using Random Forest Algorithm)
#
# For this project we will be exploring publicly available data from [LendingClub.com](www.lendingclub.com). Lending Club connects people who need money (borrowers) with people who have money (investors). Hopefully, as an investor you would want to invest in people who showed a profile of having a high probability of paying you back. We will try to create a model that will help predict this.
#
# Lending club had a [very interesting year in 2016](https://en.wikipedia.org/wiki/Lending_Club#2016), so let's check out some of their data and keep the context in mind. This data is from before they even went public.
#
# We will use lending data from 2007-2010 and be trying to classify and predict whether or not the borrower paid back their loan in full. You can download the data from [here](https://www.lendingclub.com/info/download-data.action) or just use the csv already provided. It's recommended you use the csv provided as it has been cleaned of NA values.
#
# Here are what the columns represent:
#
# * credit.policy: 1 if the customer meets the credit underwriting criteria of LendingClub.com, and 0 otherwise.
# * purpose: The purpose of the loan (takes values "credit_card", "debt_consolidation", "educational", "major_purchase", "small_business", and "all_other").
# * int.rate: The interest rate of the loan, as a proportion (a rate of 11% would be stored as 0.11). Borrowers judged by LendingClub.com to be more risky are assigned higher interest rates.
# * installment: The monthly installments owed by the borrower if the loan is funded.
# * log.annual.inc: The natural log of the self-reported annual income of the borrower.
# * dti: The debt-to-income ratio of the borrower (amount of debt divided by annual income).
# * fico: The FICO credit score of the borrower.
# * days.with.cr.line: The number of days the borrower has had a credit line.
# * revol.bal: The borrower's revolving balance (amount unpaid at the end of the credit card billing cycle).
# * revol.util: The borrower's revolving line utilization rate (the amount of the credit line used relative to total credit available).
# * inq.last.6mths: The borrower's number of inquiries by creditors in the last 6 months.
# * delinq.2yrs: The number of times the borrower had been 30+ days past due on a payment in the past 2 years.
# * pub.rec: The borrower's number of derogatory public records (bankruptcy filings, tax liens, or judgments).

# %% [markdown]
# # Import Libraries
#
# **Import the usual libraries for pandas and plotting. You can import sklearn later on.**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Get the Data
#
# **Use pandas to read loan_data.csv as a dataframe called loans.**

# %%
loans = pd.read_csv('loan_data.csv')

# %%
loans
# Out:
#       credit.policy             purpose  int.rate  installment  \
# 0                 1  debt_consolidation    0.1189       829.10
# 1                 1         credit_card    0.1071       228.22
# 2                 1  debt_consolidation    0.1357       366.86
# 3                 1  debt_consolidation    0.1008       162.34
# 4                 1         credit_card    0.1426       102.92
# ...             ...                 ...       ...          ...
# 9573              0           all_other    0.1461       344.76
# 9574              0           all_other    0.1253       257.70
# 9575              0  debt_consolidation    0.1071        97.81
# 9576              0    home_improvement    0.1600       351.58
# 9577              0  debt_consolidation    0.1392       853.43
#
#       log.annual.inc    dti  fico  days.with.cr.line  revol.bal  revol.util  \
# 0          11.350407  19.48   737        5639.958333      28854        52.1
# ...

# %% [markdown]
# **Check out the info(), head(), and describe() methods on loans.**

# %%
loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
loans.describe()
# Out:
#        credit.policy     int.rate  installment  log.annual.inc          dti  \
# count    9578.000000  9578.000000  9578.000000     9578.000000  9578.000000
# mean        0.804970     0.122640   319.089413       10.932117    12.606679
# std         0.396245     0.026847   207.071301        0.614813     6.883970
# min         0.000000     0.060000    15.670000        7.547502     0.000000
# 25%         1.000000     0.103900   163.770000       10.558414     7.212500
# 50%         1.000000     0.122100   268.950000       10.928884    12.665000
# 75%         1.000000     0.140700   432.762500       11.291293    17.950000
# max         1.000000     0.216400   940.140000       14.528354    29.960000
#
#               fico  days.with.cr.line     revol.bal   revol.util  \
# count  9578.000000        9578.000000  9.578000e+03  9578.000000
# mean    710.846314        4560.767197  1.691396e+04    46.799236
# std      37.970537        2496.930377  3.375619e+04    29.014417
# ...

# %%
loans.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# Let's do some data visualization! We'll use seaborn and pandas built-in plotting capabilities, but feel free to use whatever library you want.
#
# **Create a histogram of two FICO distributions on top of each other, one for each credit.policy outcome.**

# %%
plt.figure(figsize=(20,12))
loans[loans['credit.policy']==1]['fico'].hist(bins=40,color='blue',label='Credit Policy = 1')
loans[loans['credit.policy']==0]['fico'].hist(bins=40,color='red',label='Credit Policy = 0', alpha=0.8)
plt.legend()
plt.xlabel("FICO", size=22)
plt.tight_layout()

# %% [markdown]
# ### Visualization Inferences :
#
# * To see above graph we can tell that I have more people in my dataset that have a credit policy equal to **1** than a credit policy equal to **0**.
# * We can also tell that people have lower **FICO Score** have a credit policy of **0**.
# * If any one hase FICO Score less than arround 670 will automatically not meet the credit underwriting criteria of **LendingClub.com.**

# %% [markdown]
# **Create a similar figure, except this time select by the not.fully.paid column.**

# %%
plt.figure(figsize=(20,12))
loans[loans['not.fully.paid']==0]['fico'].hist(bins=40,color='red',label='not.fully.paid = 0')
loans[loans['not.fully.paid']==1]['fico'].hist(bins=40,color='blue',label='not.fully.paid = 1')
plt.legend()
plt.xlabel("FICO", size=22)
plt.tight_layout()

# %% [markdown]
# **Create a countplot using seaborn showing the counts of loans by purpose, with the color hue defined by not.fully.paid.**

# %%
plt.figure(figsize=(20,12))
sns.countplot(x='purpose', hue='not.fully.paid', data=loans, palette='Set1')
plt.grid()
plt.tight_layout()

# %% [markdown]
# ### Visualization Inferences :
#
# * Just by looking above plot we can tell that **dept consolidation** seems to be the most popular reason for wanting a loan.
# * Ratio of the fully paid to the not fully paid seems to be pretty similar between all reasons.

# %% [markdown]
# **Let's see the trend between FICO score and interest rate. Recreate the following jointplot.**

# %%
sns.set_style('darkgrid')
sns.jointplot(x='fico', y='int.rate', data=loans, color='purple', height=10)

# %% [markdown]
# ### Visualization Inferences :
# * To see above jointplot we can say that if your FICO Score increases, you have better credit so, interest rate on your loan is probably is going to lower and vice-versa.

# %% [markdown]
# **Create the following lmplots to see if the trend differed between not.fully.paid and credit.policy. Check the documentation for lmplot() if you can't figure out how to separate it into columns.**

# %%
sns.set_style('whitegrid')
sns.lmplot(x='fico',y='int.rate', data=loans, hue='credit.policy', palette='Set1', col='not.fully.paid', height=7)
plt.tight_layout()

# %% [markdown]
# ### Visualization Inferences :
# * In above plots we can see that the behaviour is relatively same, whether or not it was fully paid off or on, and whether or not they were denied the credit policy.

# %% [markdown]
# # Setting up the Data
#
# Let's get ready to set up our data for our Random Forest Classification Model!
#
# **Check loans.info() again.**

# %%
loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %% [markdown]
# ## Categorical Features
#
# Notice that the **purpose** column as categorical
#
# That means we need to transform them using dummy variables so sklearn will be able to understand them. Let's do this in one clean step using pd.get_dummies.
#
# Let's show you a way of dealing with these columns that can be expanded to multiple categorical features if necessary.
#
# **Create a list of 1 element containing the string 'purpose'. Call this list cat_feats.**

# %%
cat_feats = ['purpose']
cat_feats
# Out:
# ['purpose']

# %% [markdown]
# **Now use pd.get_dummies(loans,columns=cat_feats,drop_first=True) to create a fixed larger dataframe that has new feature columns with dummy variables. Set this dataframe as final_data.**

# %%
final_data = pd.get_dummies(loans, columns=cat_feats, drop_first=True)

# %%
final_data
# Out:
#       credit.policy  int.rate  installment  log.annual.inc    dti  fico  \
# 0                 1    0.1189       829.10       11.350407  19.48   737
# 1                 1    0.1071       228.22       11.082143  14.29   707
# 2                 1    0.1357       366.86       10.373491  11.63   682
# 3                 1    0.1008       162.34       11.350407   8.10   712
# 4                 1    0.1426       102.92       11.299732  14.97   667
# ...             ...       ...          ...             ...    ...   ...
# 9573              0    0.1461       344.76       12.180755  10.39   672
# 9574              0    0.1253       257.70       11.141862   0.21   722
# 9575              0    0.1071        97.81       10.596635  13.09   687
# 9576              0    0.1600       351.58       10.819778  19.18   692
# 9577              0    0.1392       853.43       11.264464  16.28   732
#
#       days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# ...

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   credit.policy               9578 non-null   int64
#  1   int.rate                    9578 non-null   float64
#  2   installment                 9578 non-null   float64
#  3   log.annual.inc              9578 non-null   float64
#  4   dti                         9578 non-null   float64
#  5   fico                        9578 non-null   int64
#  6   days.with.cr.line           9578 non-null   float64
#  7   revol.bal                   9578 non-null   int64
#  8   revol.util                  9578 non-null   float64
#  9   inq.last.6mths              9578 non-null   int64
#  10  delinq.2yrs                 9578 non-null   int64
#  11  pub.rec                     9578 non-null   int64
#  12  not.fully.paid              9578 non-null   int64
# ...

# %% [markdown]
# ## Train Test Split
#
# Now its time to split our data into a training set and a testing set!
#
# **Use sklearn to split your data into a training set and a testing set.**

# %%
# Import the model
from sklearn.model_selection import train_test_split

# %%
# Define Feature matrix
# Dimension : (9578x18)
X = final_data.drop('not.fully.paid',axis=1)
X
# Out:
#       credit.policy  int.rate  installment  log.annual.inc    dti  fico  \
# 0                 1    0.1189       829.10       11.350407  19.48   737
# 1                 1    0.1071       228.22       11.082143  14.29   707
# 2                 1    0.1357       366.86       10.373491  11.63   682
# 3                 1    0.1008       162.34       11.350407   8.10   712
# 4                 1    0.1426       102.92       11.299732  14.97   667
# ...             ...       ...          ...             ...    ...   ...
# 9573              0    0.1461       344.76       12.180755  10.39   672
# 9574              0    0.1253       257.70       11.141862   0.21   722
# 9575              0    0.1071        97.81       10.596635  13.09   687
# 9576              0    0.1600       351.58       10.819778  19.18   692
# 9577              0    0.1392       853.43       11.264464  16.28   732
#
#       days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# ...

# %%
# Define Output vector
# Dimension : (9578x1)
y = final_data['not.fully.paid']
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 9573    1
# 9574    1
# 9575    1
# 9576    1
# 9577    1
# Name: not.fully.paid, Length: 9578, dtype: int64

# %%
# Now split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)

# %%
# Check training feature matrix
# Dimension : (6704x18)
X_train
# Out:
#       credit.policy  int.rate  installment  log.annual.inc    dti  fico  \
# 4845              1    0.1426       548.90       10.714418  14.67   682
# 6910              1    0.0774       312.19       10.819778   0.86   772
# 8146              0    0.1520       208.59       10.491274  18.53   642
# 7113              1    0.1385       511.56       10.950807  12.74   682
# 195               1    0.1059       130.18       11.034890  17.81   682
# ...             ...       ...          ...             ...    ...   ...
# 599               1    0.1671       710.18       11.082143  20.09   662
# 5695              1    0.1496       164.57       10.162770  22.36   662
# 8006              0    0.1659       531.74       10.616437  20.53   652
# 1361              1    0.0907       238.75       11.002100   4.86   752
# 1547              1    0.0800       142.59       10.978490   5.58   757
#
#       days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# ...

# %%
# Check training output vector
# Dimension : (6704x1)
y_train
# Out:
# 4845    1
# 6910    0
# 8146    1
# 7113    0
# 195     0
#        ..
# 599     0
# 5695    1
# 8006    0
# 1361    0
# 1547    0
# Name: not.fully.paid, Length: 6704, dtype: int64

# %%
# Check test feature matrix
# Dimension : (2874x18)
X_test
# Out:
#       credit.policy  int.rate  installment  log.annual.inc    dti  fico  \
# 5244              1    0.1287       274.12       10.933107  23.57   687
# 1739              1    0.1347       805.67       11.695247  24.50   712
# 2780              1    0.0768       124.77       10.545341  13.45   802
# 7062              1    0.1099       274.98       10.858999  18.62   702
# 6661              1    0.1913       550.81       11.736069   9.96   687
# ...             ...       ...          ...             ...    ...   ...
# 9508              0    0.1218       466.20       10.736310   5.32   727
# 4348              1    0.0894       111.21       10.239960   1.71   727
# 4233              1    0.1253       167.34        9.862666  12.06   687
# 5363              1    0.2017       447.01       11.225243  11.25   672
# 6599              1    0.1183       795.22       11.982929  12.63   812
#
#       days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# ...

# %%
# Check test output vector
# Dimension : (2874x1)
y_test
# Out:
# 5244    0
# 1739    0
# 2780    0
# 7062    0
# 6661    0
#        ..
# 9508    0
# 4348    0
# 4233    0
# 5363    0
# 6599    0
# Name: not.fully.paid, Length: 2874, dtype: int64

# %%
##### Dimensions #####
# final_data = (9578x19)
# X_train = (6704x18)
# y_train = (6704x1)
# X_test = (2874x18)
# y_test = (2874x1)

# %% [markdown]
# ## Training a Decision Tree Model
#
# Let's start by training a single decision tree first!
#
# **Import DecisionTreeClassifier**

# %%
# Import the model for Decision Tree Classification
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# **Create an instance of DecisionTreeClassifier() called dtree and fit it to the training data.**

# %%
# Create a 'DecisionTreeClassifier' object
dtree = DecisionTreeClassifier()

# %%
# Now train our model with training data (X_train, y_train)
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# Now our model has been trained.

# %% [markdown]
# ## Predictions and Evaluation of Decision Tree
# **Create predictions from the test set and create a classification report and a confusion matrix.**

# %%
# Now make predictions with our test data (X_test)
predictions = dtree.predict(X_test)

# %%
predictions
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %%
# Import the model for classification_report and confusion_matrix
from sklearn.metrics import classification_report,confusion_matrix

# %%
# Print confusion matrix with 'y_test' and 'predictions'
print(confusion_matrix(y_test, predictions))
# Out:
# [[1983  448]
#  [ 344   99]]

# %%
# Print classification report with 'y_test' and 'predictions'
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.82      0.83      2431
#            1       0.18      0.22      0.20       443
#
#     accuracy                           0.72      2874
#    macro avg       0.52      0.52      0.52      2874
# weighted avg       0.75      0.72      0.74      2874

# %% [markdown]
# ## Training the Random Forest model
#
# Now its time to train our model!
#
# **Create an instance of the RandomForestClassifier class and fit it to our training data from the previous step.**

# %%
# Import the model for random forest classifier
from sklearn.ensemble import RandomForestClassifier

# %%
# Create a RandomForestClassifier model with 500 number-of-estimators (number-of-Decision-Trees)
rfc = RandomForestClassifier(n_estimators=500)

# %%
# Train our model with training data (X_train, y_train)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=500)

# %% [markdown]
# ## Predictions and Evaluation
#
# Now our model has been trained, Let's predict off the y_test values and evaluate our model.
#
# **Predict the class of not.fully.paid for the X_test data.**

# %%
# Now make predictions with test data (X_test)
rfc_pred = rfc.predict(X_test)

# %%
rfc_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %% [markdown]
# **Now create a classification report from the results. Do you get anything strange or some sort of warning?**

# %%
# Print classification report with 'y_test' and 'predictions'
print(classification_report(y_test, rfc_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92      2431
#            1       0.56      0.02      0.04       443
#
#     accuracy                           0.85      2874
#    macro avg       0.70      0.51      0.48      2874
# weighted avg       0.80      0.85      0.78      2874

# %% [markdown]
# **Show the Confusion Matrix for the predictions.**

# %%
# Print confusion matrix with 'y_test' and 'predictions'
print(confusion_matrix(y_test, rfc_pred))
# Out:
# [[2423    8]
#  [ 433   10]]

# %%
final_data['not.fully.paid'].value_counts()
# Out:
# 0    8045
# 1    1533
# Name: not.fully.paid, dtype: int64

# %% [markdown]
# ### **What performed better the random forest or the decision tree?**

# %% [markdown]
# * **Overall performance of Random Forest model is better than Decision Tree model.**
# * **F1-Score** and **Accuracy** is better in Random forest that Decision tree model.
# * But, the **recall for instance for the class-1** is better in Decision tree than Random forest model.

# %% [markdown]
# ### Note :
#
# * Depends what metric you are trying to optimize for.
# * Notice the recall for each class for the models.
# * Neither did very well, more feature engineering is needed.

# %% [markdown]
# # Great Job !
